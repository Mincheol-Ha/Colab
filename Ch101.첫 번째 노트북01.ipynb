# %% [markdown]
# # **Python ML 첫 번째 노트북**

# %%
import numpy as np
import pandas as pd
import sklearn  # sciit-learn 패키지
import tensorflow as tf # 신경망 알고리즘 패키지
print(np.__version__)
print(pd.__version__)
print(sklearn.__version__)
print(tf.__version__)
# Out:
# 1.26.4
# 2.2.2
# 1.5.2
# 2.17.1
